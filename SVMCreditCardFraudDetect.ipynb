# %% [markdown]
# <a href="https://colab.research.google.com/github/BhavyaSrinivas2003/CreditCardFraudDetect/blob/main/SVMCreditCardFraudDetect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **GATHERING DATA from kaggle**

# %%
#Installing kaggle module
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Command Notations:**
# * mkdir--make Directory
# * cp-- copy
# * chmod--change mode
# *json--JavaScriptObjectNotation

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Dataset Command Path

# %%
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# Out:
# ...
#  86% 57.0M/66.0M [00:00<00:00, 93.6MB/s]
# 100% 66.0M/66.0M [00:00<00:00, 81.1MB/s]

# %%
#extracting zip file
from zipfile import ZipFile
dataset="/content/creditcardfraud.zip"
with ZipFile(dataset,'r')as zip:
  zip.extractall()
  print("The data is extracted")
# Out:
# The data is extracted

# %%
print(dataset)
# Out:
# /content/creditcardfraud.zip

# %%
import pandas as pd

# %%
Data=pd.read_csv("/content/creditcard.csv")
Data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# **PREPARING THE DATA**

# %%
#importing standard libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
#importing svm model
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
Dataset=pd.read_csv("/content/creditcard.csv")
print(Dataset)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
Dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
Dataset.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
Dataset.shape
# Out:
# (284807, 31)

# %% [markdown]
# **FINDING NULL VALUES**

# %%
Dataset.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# **Checking wheather the data is balanced or unbalanced**

# %%
Dataset["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# Hence the data is clearly unbalanced. and we need to convert it into Balanced format.

# %% [markdown]
# **CLASSIFYING VALID USER AND FRAUD USER**

# %%
valid=Dataset[Dataset.Class==0]
valid
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud=Dataset[Dataset.Class==1]
fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %% [markdown]
# **CONVERTING TO BALANCED DATA USING SAMPLING**

# %%
valid_sample=valid.sample(n=len(fraud))
valid_sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 155615  105904.0  1.972265 -0.464781 -1.626202 -0.593907  1.901315  3.742424
# 58327    48332.0  1.159757  0.222481  0.237549  1.089785 -0.138051 -0.498851
# 268331  163157.0  1.932350 -0.466472 -0.453639  0.166694 -0.540701 -0.302526
# 118896   75249.0 -1.142650  0.418000  1.472538 -1.084475 -0.260661 -0.992462
# 184416  126233.0 -1.329959 -0.123651  0.933031 -3.086828 -0.494215 -0.546785
# ...          ...       ...       ...       ...       ...       ...       ...
# 106073   69810.0 -1.375364  1.228114  1.136320 -0.005838  0.048109 -0.472369
# 71928    54499.0  1.106163  0.251623  0.509677  1.354759 -0.465662 -1.021819
# 158492  111338.0 -1.787262 -1.272808  1.992868 -1.918383  0.814814 -0.931105
# 280325  169456.0 -1.806268  2.117882 -0.549426  0.806450  0.230671 -0.236108
# 274051  165830.0  2.249375 -1.506309 -0.753225 -1.659968 -1.345344 -0.325434
#
# ...

# %% [markdown]
# **Rechecking for Balanced Data**

# %%
print(valid_sample.shape)
print(fraud.shape)
# Out:
# (492, 31)
# (492, 31)

# %% [markdown]
# hence the data is balanced.Hence combining both Valid & Fraud Users to form a new dataset

# %%
new_Dataset=pd.concat([valid_sample,fraud],axis=0)
new_Dataset
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 155615  105904.0  1.972265 -0.464781 -1.626202 -0.593907  1.901315  3.742424
# 58327    48332.0  1.159757  0.222481  0.237549  1.089785 -0.138051 -0.498851
# 268331  163157.0  1.932350 -0.466472 -0.453639  0.166694 -0.540701 -0.302526
# 118896   75249.0 -1.142650  0.418000  1.472538 -1.084475 -0.260661 -0.992462
# 184416  126233.0 -1.329959 -0.123651  0.933031 -3.086828 -0.494215 -0.546785
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
new_Dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 155615  105904.0  1.972265 -0.464781 -1.626202 -0.593907  1.901315  3.742424
# 58327    48332.0  1.159757  0.222481  0.237549  1.089785 -0.138051 -0.498851
# 268331  163157.0  1.932350 -0.466472 -0.453639  0.166694 -0.540701 -0.302526
# 118896   75249.0 -1.142650  0.418000  1.472538 -1.084475 -0.260661 -0.992462
# 184416  126233.0 -1.329959 -0.123651  0.933031 -3.086828 -0.494215 -0.546785
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 155615 -1.173426  0.927211  2.441938  ... -0.265432 -0.511603  0.396600
# 58327   0.143770 -0.079237  0.032431  ...  0.063782  0.199615 -0.083720
# 268331 -0.510143  0.044381  0.782174  ... -0.215570 -0.610643  0.366772
# 118896  0.228642  0.204537 -0.305246  ...  0.061036  0.011380 -0.055293
# 184416 -0.311817  0.351724 -2.682353  ... -0.142919  0.014963 -0.164697
#
# ...

# %%
new_Dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_Dataset.shape
# Out:
# (984, 31)

# %% [markdown]
# **Rechecking for Null Values**

# %%
new_Dataset.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
new_Dataset["Class"].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %% [markdown]
# Hence the data is balanced.Now,
# * Splitting the data into 2 variables ---x & y taking target function in y--variable and data in x--variable

# %% [markdown]
# Using drop method

# %%
x=new_Dataset.drop("Class",axis=1)
x
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 155615  105904.0  1.972265 -0.464781 -1.626202 -0.593907  1.901315  3.742424
# 58327    48332.0  1.159757  0.222481  0.237549  1.089785 -0.138051 -0.498851
# 268331  163157.0  1.932350 -0.466472 -0.453639  0.166694 -0.540701 -0.302526
# 118896   75249.0 -1.142650  0.418000  1.472538 -1.084475 -0.260661 -0.992462
# 184416  126233.0 -1.329959 -0.123651  0.933031 -3.086828 -0.494215 -0.546785
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
y=new_Dataset.Class
y
# Out:
# 155615    0
# 58327     0
# 268331    0
# 118896    0
# 184416    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# Data Standardization

# %%
scaler=StandardScaler()
scaler.fit(x)
# Out:
# StandardScaler()

# %%
Standardised_data=scaler.transform(x)
Standardised_data
# Out:
# array([[ 0.36963619,  0.78078391, -0.5742262 , ..., -0.01730226,
#         -0.18342115, -0.24808736],
#        [-0.83314394,  0.63435341, -0.39766899, ..., -0.04379108,
#         -0.04330238, -0.21199302],
#        [ 1.56575185,  0.77359053, -0.5746607 , ..., -0.1146682 ,
#         -0.21687591, -0.19125986],
#        ...,
#        [ 1.69515538,  0.30348695, -0.16546171, ...,  0.31055595,
#          0.37699723, -0.09602942],
#        [ 1.70800381, -0.13583429, -0.30431624, ...,  0.80067245,
#         -0.70224105,  0.27492534],
#        [ 1.71598446,  0.78433633, -0.41411197, ..., -0.06418437,
#         -0.12803178, -0.17452239]])

# %% [markdown]
# Now taking this standardised data as x value because it has to be suitable for all the data

# %%
x=Standardised_data

# %%
print(x)
# Out:
# [[ 0.36963619  0.78078391 -0.5742262  ... -0.01730226 -0.18342115
#   -0.24808736]
#  [-0.83314394  0.63435341 -0.39766899 ... -0.04379108 -0.04330238
#   -0.21199302]
#  [ 1.56575185  0.77359053 -0.5746607  ... -0.1146682  -0.21687591
#   -0.19125986]
#  ...
#  [ 1.69515538  0.30348695 -0.16546171 ...  0.31055595  0.37699723
#   -0.09602942]
#  [ 1.70800381 -0.13583429 -0.30431624 ...  0.80067245 -0.70224105
#    0.27492534]
#  [ 1.71598446  0.78433633 -0.41411197 ... -0.06418437 -0.12803178
#   -0.17452239]]

# %%
print(y)
# Out:
# 155615    0
# 58327     0
# 268331    0
# 118896    0
# 184416    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# Splitting the data into train_data (80%) and test_data(20%) and taking shuffle_state nothing but random_state as 3

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %% [markdown]
# In above test_size means 20% of test_data

# %% [markdown]
# Printing the shapes of train_data and test_data

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
print(y.shape,y_train.shape,y_test.shape)
# Out:
# (984,) (787,) (197,)

# %% [markdown]
# **Using SVM Model**

# %% [markdown]
# Training the model

# %%
classifier=svm.SVC(kernel="linear")

# %% [markdown]
# SVC--Support Vector Classifier

# %%
#train the support vector machine classifier
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
print(classifier)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# **Model Evaluation**

# %% [markdown]
# * based on accuracy score
# * 2 ways
#
#  * making prediction for the same data i.e test-data
#  * making prediction for new data

# %%
#finding accuracy_score for the train_data
x_train_prediction= classifier.predict(x_train)
training_data_accuracy= accuracy_score(x_train_prediction, y_train)
print("Accuracy score of Train Data: ", training_data_accuracy)
# Out:
# Accuracy score of Train Data:  0.9479034307496823

# %%
#finding accuracy_score for the test_data
x_test_prediction=classifier.predict(x_test)
test_data_accuracy= accuracy_score(x_test_prediction, y_test)
print("Accuracy score of Test Data: ", test_data_accuracy)
# Out:
# Accuracy score of Test Data:  0.949238578680203

# %% [markdown]
# Making Prediction

# %%
input_data=[172792,-0.533412522,-0.189733337,0.703337367,-0.50627124,-0.012545679,-0.649616686,1.577006254,-0.414650408,0.486179505,-0.915426649,-1.040458335,-0.031513054,-0.188092901,-0.08431647,0.041333455,-0.302620086,-0.660376645,0.167429934,-0.256116871,0.382948105,0.261057331,0.643078438,0.376777014,0.008797379,0.473648704,-0.818267121,-0.002415309,0.013648914,217]

#converting it into numpy array
input_data_as_numpy_array=np.array(input_data)
#reshaping the array since we are predicting
input_data_reshaped= input_data_as_numpy_array.reshape(1,-1)
#Standardise  the input data
std_data=scaler.transform(input_data_reshaped)
print(std_data)
prediction=classifier.predict(std_data)
print(prediction)
if prediction[0]==0:
  print("The Credit Card is valid")
elif prediction[0]==1:
  print("The Credit Card is fraud")
# Out:
# [[ 1.76704391  0.32920983 -0.50356666  0.67766529 -0.87957947  0.37525349
#    0.04467089  0.73683203 -0.13873771  0.77293401  0.42828061 -1.06728562
#    0.67393947 -0.10865253  0.72900167  0.11026122  0.50510299  0.44511687
#    0.52542181 -0.4249678   0.12484866 -0.03808747  0.52154529  0.34488034
#    0.09121145  0.65338384 -1.7849437  -0.06948292 -0.05828183  0.21277027]]
# [0]
# The Credit Card is valid
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Making Prediction

# %% [markdown]
# **CONCLUSION**
# * The accuracy of Test Data using SVM is 94.9%
# * Hence the test result and prediction result are  more accurate hence we can say that the SVM model is more optimal.
